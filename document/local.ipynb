# %%
from qiskit_nature.converters.second_quantization import QubitConverter
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit.circuit.library import ExcitationPreserving
from qiskit_nature.circuit.library import HartreeFock
from qiskit.quantum_info import PauliList

# %%
def create_H_circ():
  converter = QubitConverter(JordanWignerMapper())
  num_particles = (1,1)
  num_spin_orbitals = 4
  init = HartreeFock(num_spin_orbitals, num_particles, converter)

  reps = 1

  var_form = ExcitationPreserving(
    num_spin_orbitals, 'iswap', 'linear', reps
  )
  var_form.compose(init, front=True, inplace=True)
  return var_form.decompose()

qc = create_H_circ()
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/pyx64/lib/python3.11/site-packages/qiskit_nature/deprecation.py:297: PauliSumOpDeprecationWarning: PauliSumOp is deprecated as of version 0.6.0 and support for them will be removed no sooner than 3 months after the release. Instead, use SparsePauliOp. You can switch to SparsePauliOp immediately, by setting `qiskit_nature.settings.use_pauli_sum_op` to `False`.
#   return func(*args, **kwargs)

# %%
qc.draw(output='mpl')
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/pyx64/lib/python3.11/site-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
